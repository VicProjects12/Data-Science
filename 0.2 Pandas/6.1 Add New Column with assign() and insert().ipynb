# %%
import pandas as pd

# %%
# reading the csv files
df_exams = pd.read_csv('/Users/vic/Downloads/StudentsPerformance.csv')
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# # Adding a new column

# %% [markdown]
# #1.1 assign

# %% [markdown]
# When to use assign?
#     . Add multiple columns in a single line of code
#     . When you need to overwrite the values of an existing column (best practice)
# It returns a new object (a copy) with all the original columns in addition to the new ones

# %%
import numpy as np

# %%
# Create random numbers for our new score columns
score1 = np.random.randint(1, 100, size=1000)
score2 = np.random.randint(1, 100, size=1000)

# %%
# Create a series using random numbers
series1 = pd.Series(score1, index=np.arange(0, 1000))
series2 = pd.Series(score2, index=np.arange(0, 1000))

# %%
series1
# Out:
# 0      10
# 1      41
# 2      31
# 3      25
# 4      10
#        ..
# 995    66
# 996    32
# 997     7
# 998     8
# 999    44
# Length: 1000, dtype: int64

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
# using assign() to add multiple columns
df_exams.assign(score1=series1, score2=series2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  score1  \
# 0                      none          72             72             74      10
# 1                 completed          69             90             88      41
# 2                      none          90             95             93      31
# 3                      none          47             57             44      25
# 4                      none          76             78             75      10
# ..                      ...         ...            ...            ...     ...
# 995               completed          88             99             95      66
# 996                    none          62             55             55      32
# 997               completed          59             71             65       7
# 998               completed          68             78             77       8
# 999                    none          77             86             86      44
#
#      score2
# 0        67
# 1        94
# 2        83
# 3        45
# 4        17
# ..      ...
# 995      19
# 996      99
# 997      31
# 998      80
# 999      16
#
# [1000 rows x 10 columns]

# %%
# using assign() to add multiple columns
df_exams = df_exams.assign(score1=series1, score2=series2)

# %%
# Show dataframe
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  score1  \
# 0                      none          72             72             74      10
# 1                 completed          69             90             88      41
# 2                      none          90             95             93      31
# 3                      none          47             57             44      25
# 4                      none          76             78             75      10
# ..                      ...         ...            ...            ...     ...
# 995               completed          88             99             95      66
# 996                    none          62             55             55      32
# 997               completed          59             71             65       7
# 998               completed          68             78             77       8
# 999                    none          77             86             86      44
#
#      score2
# 0        67
# 1        94
# 2        83
# 3        45
# 4        17
# ..      ...
# 995      19
# 996      99
# 997      31
# 998      80
# 999      16
#
# [1000 rows x 10 columns]

# %% [markdown]
# # 1.2 insert()
#
# Inserts a new column at a specific position or index

# %%
# using index() to add a column at a specific position
df_exams.insert(1, 'test', series1)

# %%
# show dataframe
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    10        group B           bachelor's degree      standard
# 1    female    41        group C                some college      standard
# 2    female    31        group B             master's degree      standard
# 3      male    25        group A          associate's degree  free/reduced
# 4      male    10        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    66        group E             master's degree      standard
# 996    male    32        group C                 high school  free/reduced
# 997  female     7        group C                 high school  free/reduced
# 998  female     8        group D                some college      standard
# 999  female    44        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  score1  \
# 0                      none          72             72             74      10
# 1                 completed          69             90             88      41
# 2                      none          90             95             93      31
# 3                      none          47             57             44      25
# 4                      none          76             78             75      10
# ..                      ...         ...            ...            ...     ...
# 995               completed          88             99             95      66
# 996                    none          62             55             55      32
# 997               completed          59             71             65       7
# 998               completed          68             78             77       8
# 999                    none          77             86             86      44
#
#      score2
# 0        67
# 1        94
# 2        83
# 3        45
# 4        17
# ..      ...
# 995      19
# 996      99
# 997      31
# 998      80
# 999      16
#
# [1000 rows x 11 columns]
